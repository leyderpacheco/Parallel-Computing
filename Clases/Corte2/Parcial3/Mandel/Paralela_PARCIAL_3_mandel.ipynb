# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/leyderpacheco/data1/main/resultados.csv')

# %%
datos
# Out:
#     n_steps  tiempo_python  tiempo_cython    speedup
# 0       100       0.093865       0.002300  40.818870
# 1       200       0.387754       0.008994  43.110855
# 2       300       0.877529       0.020002  43.871257
# 3       400       1.543531       0.035220  43.824938
# 4       500       2.395267       0.053605  44.683790
# 5       600       3.593207       0.072326  49.680415
# 6       700       4.969115       0.101463  48.974728
# 7       800       6.482323       0.124031  52.263806
# 8       900       7.891414       0.157659  50.053594
# 9      1000       9.988600       0.193090  51.730165
# 10     1100      12.238652       0.231201  52.935024
# 11     1200      14.102613       0.280469  50.282262

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['tiempo_python'])
plt.plot(datos["n_steps"],datos['tiempo_cython'])
plt.legend(["python","cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['speedup'])
plt.legend(["python/cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()
