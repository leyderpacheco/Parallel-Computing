# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/leyderpacheco/data1/main/resultados.csv')

# %%
datos
# Out:
#     n_steps  tiempo_python  tiempo_cython     speedup
# 0        50       2.636021       0.006976  377.863021
# 1       100       4.968347       0.014250  348.666605
# 2       150       7.389381       0.021380  345.622020
# 3       200      10.039923       0.028343  354.223879
# 4       250      12.599761       0.034326  367.058350
# 5       300      15.824064       0.041298  383.164203
# 6       350      17.698417       0.051600  342.989544
# 7       400      20.166299       0.059205  340.620601
# 8       450      23.694413       0.066311  357.324431
# 9       500      25.525694       0.070240  363.405470
# 10      550      28.589236       0.080292  356.063750
# 11      600      30.850030       0.084467  365.231000
# 12      650      33.915710       0.095780  354.098745
# 13      700      36.546085       0.100117  365.034747
# 14      750      39.229679       0.106349  368.875179
# 15      800      41.805622       0.113994  366.734127
# 16      850      44.333367       0.125098  354.389798
# 17      900      47.023571       0.132379  355.219760
# 18      950      49.728400       0.139851  355.581666
# 19     1000      52.308996       0.142458  367.188999
# 20     1050      56.719779       0.154384  367.393259
# 21     1100      57.715904       0.161835  356.634353
# 22     1150      60.196752       0.169085  356.015685

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['tiempo_python'])
plt.plot(datos["n_steps"],datos['tiempo_cython'])
plt.legend(["python","cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()

# %%
plt.rcParams['figure.figsize']=[16,8]
plt.title("Comparativa de rendimiento entre python y cython")
plt.plot(datos["n_steps"],datos['speedup'])
plt.legend(["python/cython"])
plt.xlabel("Número de pasos")
plt.ylabel("Tiempo (Seg)")
plt.grid()
plt.show()
